# %% [markdown]
# <a href="https://colab.research.google.com/github/maekawaka/php-5.5-windows-extensions/blob/master/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-cloud-vision
# Out:
# Requirement already up-to-date: google-cloud-vision in /usr/local/lib/python3.6/dist-packages (1.0.0)
# ...

# %%
import os
import os.path
import errno

from googleapiclient import discovery
from oauth2client.client import GoogleCredentials

cred_path = '/content/MyProject-031e79118651.json'

if os.path.exists(cred_path) == False:
  raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), cred_path)

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = cred_path

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib

# %%
import platform

# %%
input_file = '/content/menkyo.JPG'
img = cv2.imread(input_file) # input_fileは画像のパス
plt.figure(figsize=[10,10])
plt.axis('off')
plt.imshow(img[:,:,::-1])

# %%
import io

from google.cloud import vision
from google.cloud.vision import types

client = vision.ImageAnnotatorClient()
with io.open(input_file, 'rb') as image_file:
    content = image_file.read()
image = types.Image(content=content)
response = client.document_text_detection(image=image)

# %%
print(response.text_annotations[0].description)
# Out:
# 氏名
# 日 本
# 花子
# 昭和40年 4月12日生)
# 住所 宇都宮市田1-1-20
# 交付 会和01年05月05日 12345
# 2024年(今和06年05月12日下有效
# 眼鏡等
# 免許の
# 条件等
# 見本
# 優良
# 番号| 第 419999999970 号
# | - 昭和60年03月03日|種
# 他「合和00年00月00日
# (三種合和00年00月00日
# 運転免許証
# 類
# 原付
# 公安委員会
# EPRO
